# %%
from IPython.display import HTML, display
import sys
from pathlib import Path

HTML("""
<style>
div.cell_input,
div.prompt {
  display: none !important;
}
</style>
""")

repo_root = Path.cwd().resolve()
while repo_root != repo_root.parent:
    if (repo_root / "icesee_jupyter_book").exists() and (repo_root / "external" / "ICESEE").exists():
        break
    repo_root = repo_root.parent

if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

# print("repo_root:", repo_root)

from icesee_jupyter_book.ui.icesee_gateway import build_icesee_ui

ui = build_icesee_ui()
display(ui)
# display(build_icesee_ui())
# Out:
# HTML(value="\n        <style>\n        /* --- your existing styles --- */\n        .icesee-wrap { font-family:…
# VBox(children=(HTML(value="<div class='icesee-wrap'><div class='icesee-title'>Run ICESEE examples with one cli…
